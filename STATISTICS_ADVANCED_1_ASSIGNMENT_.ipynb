# %% [markdown]
# STATISTICS ADVANCED 1 - ASSIGNMENT
#
# 1. What is a random variable in probability theory?
# - In probability theory, a random variable is a variable that represents the outcomes of a random phenomenon or experiment. It assigns a numerical value to each possible outcome in a sample space.
#
# A random variable is a function that maps outcomes of a random experiment to real numbers.
#
# Formal Definition:
#
# A random variable is a function:
#
# 𝑋
# :
# Ω
# →
# 𝑅
# X:Ω→R
# where:
#
# Ω
# Ω is the sample space (the set of all possible outcomes),
#
# 𝑋
# X assigns a real number to each outcome
# 𝜔
# ∈
# Ω
# ω∈Ω.
#
#
#
# Purpose and Role:
#
# A random variable quantifies outcomes of an experiment so we can compute probabilities, averages, variances, and other statistical properties.
#
# It provides a bridge between abstract outcomes (like drawing a card or tossing a coin) and numerical analysis.
#
# Example:
#
# Imagine an experiment where you toss a coin three times.
#
# The sample space is:
#
# Ω
# =
# {
# 𝐻
# 𝐻
# 𝐻
# ,
# 𝐻
# 𝐻
# 𝑇
# ,
# 𝐻
# 𝑇
# 𝐻
# ,
# 𝐻
# 𝑇
# 𝑇
# ,
# 𝑇
# 𝐻
# 𝐻
# ,
# 𝑇
# 𝐻
# 𝑇
# ,
# 𝑇
# 𝑇
# 𝐻
# ,
# 𝑇
# 𝑇
# 𝑇
# }
#
#
# Ω= {HHH,HHT,HTH,HTT,THH,THT,TTH,TTT}
#
#
# Define a random variable
# 𝑋
# X that counts the number of heads.
# Then, for example:
#
# 𝑋
# (
# 𝐻
# 𝐻
# 𝐻
# )
# =
# 3
# X(HHH)=3
#
# 𝑋
# (
# 𝐻
# 𝑇
# 𝑇
# )
# =
# 1
# X(HTT)=1
#
# 𝑋
# (
# 𝑇
# 𝑇
# 𝑇
# )
# =
# 0
# X(TTT)=0
#
# Here,
# 𝑋
# X maps each possible outcome (a sequence of coin tosses) to a numerical value (the count of heads).
#
# Key Properties:
# Well-defined: Each outcome maps to exactly one real number.
#
# Allows probability calculation: Once a random variable is defined, we can compute probabilities like
# 𝑃
# (
# 𝑋
# =
# 2
# )
# P(X=2).
#
# Foundation for distributions: Random variables lead to probability distributions, which describe the likelihood of different values.
#
#
#  2. What are the types of random variables?
#
# There are two main types of random variables:
#
# - Discrete Random Variable:
#
# A discrete random variable takes on a finite or countably infinite number of distinct values.
#
# ➤ Characteristics:
# Values are separate and countable (like 0, 1, 2, 3...).
#
# Associated with a probability mass function (PMF).
#
# The sum of probabilities across all possible values is 1:
#
# ∑
# 𝑃
# (
# 𝑋
# =
# 𝑥
# 𝑖
# )
# =
# 1
# ∑P(X=x
# i
# ​
#  )=1
#
# ➤ Examples:
# Number of heads in 3 coin tosses.
#
# Number of students in a classroom.
#
# Number of calls received per hour at a call center.
#
# Number of goals in a football match.
#
# ➤ Common Discrete Distributions:
# Bernoulli distribution (e.g., coin toss with success/failure)
#
# Binomial distribution (e.g., number of successes in n trials)
#
# Poisson distribution (e.g., number of events in a time interval)
#
#
# Takes on a countable number of distinct values.
#
# Example: The number of heads in 3 coin tosses.
#
# Possible values: 0, 1, 2, 3
#
# Takes a finite or countably infinite set of values.
#
# Examples:
#
# Number of students in a class
#
# Number of goals in a football match
#
# Key Tool: Probability Mass Function (PMF)
# Denoted:
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# P(X=x)
#
# Example: Tossing 2 coins
#
# 𝑋
# =
# number of heads
# X=number of heads
#
# Possible values: {0, 1, 2}
#
# PMF:
#
# 𝑃
# (
# 𝑋
# =
# 0
# )
# =
# 1
# /
# 4
# P(X=0)=1/4
#
# 𝑃
# (
# 𝑋
# =
# 1
# )
# =
# 1
# /
# 2
# P(X=1)=1/2
#
# 𝑃
# (
# 𝑋
# =
# 2
# )
# =
# 1
# /
# 4
# P(X=2)=1/4
#
# - Continuous Random Variable:
#
# A continuous random variable can take on any value within a range or interval, including infinitely many values.
#
# ➤ Characteristics:
# Values are not countable, often measured not counted.
#
# Associated with a probability density function (PDF).
#
# Probability at a specific point is zero:
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 0
# P(X=x)=0
#
# Total area under the curve of the PDF is 1:
#
# ∫
# −
# ∞
# ∞
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# =
# 1
# ∫
# −∞
# ∞
# ​
#  f(x)dx=1
#
# ➤ Examples:
# Height or weight of individuals.
#
# Time taken to complete a task.
#
# Temperature on a given day.
#
# Distance traveled by a vehicle.
#
# ➤ Common Continuous Distributions:
# Normal (Gaussian) distribution
#
# Exponential distribution
#
# Uniform distribution
#
# Beta distribution
# Takes on uncountably infinite values over an interval.
#
# Example: The time a person waits in a queue (could be 1.5 minutes, 1.52 minutes, etc.)
#
# Takes uncountably infinite values (e.g., all real numbers in an interval).
#
# Examples:
#
# Height of students
#
# Time taken to run a race
#
# Key Tool: Probability Density Function (PDF)
# Denoted:
# 𝑓
# (
# 𝑥
# )
# f(x), such that:
#
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
# Note:
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 0
# P(X=x)=0 for any exact value.
#
#
# 3.  Explain the difference between discrete and continuous distributions.
#
# Basic Definition _
#
# - Discrete Distribution
#
# A discrete probability distribution describes the probability of a discrete random variable — one that takes on countable values (often integers).
#
# Examples include: 0, 1, 2, 3, ...
#
# - Continuous Distribution
#
# A continuous probability distribution describes the probability of a continuous random variable — one that can take any value within a range or interval (uncountably infinite).
#
# Examples include: 1.24, 3.1416, or any real number in an interval like [0,1].
#
# - Probability Assignment
#
# Discrete
# Probabilities are assigned to individual values.
#
# The sum of all probabilities is exactly 1.
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# some specific value
# P(X=x)=some specific value
# Example:
# If a die is fair,
#
# 𝑃
# (
# 𝑋
# =
# 2
# )
# =
# 1
# 6
# P(X=2)=
# 6
# 1
# ​
#
# Continuous
# Probabilities are assigned to intervals of values, not specific points.
#
# The probability of any single value is zero:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 0
# P(X=x)=0
# Only:
#
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# P(a≤X≤b)
# is meaningful and non-zero.
#
# - Probability Function Type
#
# Discrete
# Uses a Probability Mass Function (PMF)
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 𝑝
# (
# 𝑥
# )
# P(X=x)=p(x)
# It gives the probability that
# 𝑋
# X takes a specific value.
#
# Continuous
# Uses a Probability Density Function (PDF)
#
# 𝑓
# (
# 𝑥
# )
# ≥
# 0
# f(x)≥0
# But:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 0
# ,
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(X=x)=0,P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
#
# - Graphical Representation
#
# Discrete: Bar chart showing spikes at each value with height = probability.
#
# Continuous: Smooth curve where the area under the curve represents probability.
#
# - Examples
#
# Discrete Distribution Examples:
# Rolling a die: outcomes = 1, 2, 3, 4, 5, 6
#
# Number of heads in 3 coin tosses
#
# Number of customer complaints in a day
#
# Continuous Distribution Examples:
# Time taken to run a race (e.g., 12.34 sec)
#
# Height of people (e.g., 168.2 cm)
#
# Temperature in a day (e.g., 37.5°C)
#
#
# 4. What is a binomial distribution, and how is it used in probability?
#
# - A binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent Bernoulli trials, where each trial has only two possible outcomes:
#
# Success (usually coded as 1)
#
# Failure (usually coded as 0)
#
# - Definition:
# A random variable
# 𝑋
# X follows a binomial distribution if:
#
# 𝑋
# ∼
# Bin
# (
# 𝑛
# ,
# 𝑝
# )
# X∼Bin(n,p)
# where:
#
# 𝑛
# n = number of trials
#
# 𝑝
# p = probability of success in each trial
#
# 𝑋
# X = number of successes in
# 𝑛
# n trials
#
# - Probability Mass Function (PMF):
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# Where:
#
# (
# 𝑛
# 𝑘
# )
# =
# 𝑛
# !
# 𝑘
# !
# (
# 𝑛
# −
# 𝑘
# )
# !
# (
# k
# n
# ​
#  )=
# k!(n−k)!
# n!
# ​
#   is the binomial coefficient
#
# 𝑘
# k = number of successes (0 ≤
# 𝑘
# k ≤
# 𝑛
# n)
#
# 𝑝
# p = probability of success
#
# (
# 1
# −
# 𝑝
# )
# (1−p) = probability of failure
#
# - Key Properties:
# Property	Value
# Mean
# 𝜇
# =
# 𝑛
# 𝑝
# μ=np
# Variance
# 𝜎
# 2
# =
# 𝑛
# 𝑝
# (
# 1
# −
# 𝑝
# )
# σ
# 2
#  =np(1−p)
# Standard Deviation
# 𝜎
# =
# 𝑛
# 𝑝
# (
# 1
# −
# 𝑝
# )
# σ=
# np(1−p)
# ​
#
# Shape	Symmetric if
# 𝑝
# =
# 0.5
# p=0.5; skewed otherwise
#
# - Conditions to Use Binomial Distribution:
# A situation follows a binomial distribution if:
#
# There is a fixed number of trials (
# 𝑛
# n).
#
# Each trial has only two outcomes (success or failure).
#
# The probability of success (
# 𝑝
# p) is the same in each trial.
#
# The trials are independent.
#
# - Examples of Use:
# Coin Tossing: Tossing a fair coin 10 times. Let
# 𝑋
# X be the number of heads.
# Then
# 𝑋
# ∼
# Bin
# (
# 10
# ,
# 0.5
# )
# X∼Bin(10,0.5)
#
# Product Defects: Checking 20 products, each has a 5% chance of being defective.
# Let
# 𝑋
# X be the number of defective products.
# 𝑋
# ∼
# Bin
# (
# 20
# ,
# 0.05
# )
# X∼Bin(20,0.05)
#
# Exam Questions: A student guesses answers to 10 true/false questions.
# The number of correct answers is binomially distributed:
# 𝑋
# ∼
# Bin
# (
# 10
# ,
# 0.5
# )
# X∼Bin(10,0.5)
#
#
# 5.  What is the standard normal distribution, and why is it important?
#
# A binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent Bernoulli trials, where each trial has only two possible outcomes:
#
# Success (usually coded as 1)
#
# Failure (usually coded as 0)
#
# - Definition:
# A random variable
# 𝑋
# X follows a binomial distribution if:
#
# 𝑋
# ∼
# Bin
# (
# 𝑛
# ,
# 𝑝
# )
# X∼Bin(n,p)
# where:
#
# 𝑛
# n = number of trials
#
# 𝑝
# p = probability of success in each trial
#
# 𝑋
# X = number of successes in
# 𝑛
# n trials
#
# - Probability Mass Function (PMF):
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# Where:
#
# (
# 𝑛
# 𝑘
# )
# =
# 𝑛
# !
# 𝑘
# !
# (
# 𝑛
# −
# 𝑘
# )
# !
# (
# k
# n
# ​
#  )=
# k!(n−k)!
# n!
# ​
#   is the binomial coefficient
#
# 𝑘
# k = number of successes (0 ≤
# 𝑘
# k ≤
# 𝑛
# n)
#
# 𝑝
# p = probability of success
#
# (
# 1
# −
# 𝑝
# )
# (1−p) = probability of failure
#
# | Property               | Value                                    |
# | ---------------------- | ---------------------------------------- |
# | **Mean**               | $\mu = np$                               |
# | **Variance**           | $\sigma^2 = np(1 - p)$                   |
# | **Standard Deviation** | $\sigma = \sqrt{np(1 - p)}$              |
# | **Shape**              | Symmetric if $p = 0.5$; skewed otherwise |
#
# - Conditions to Use Binomial Distribution:
# A situation follows a binomial distribution if:
#
# There is a fixed number of trials (
# 𝑛
# n).
#
# Each trial has only two outcomes (success or failure).
#
# The probability of success (
# 𝑝
# p) is the same in each trial.
#
# The trials are independent.
#
# - Examples of Use:
# Coin Tossing: Tossing a fair coin 10 times. Let
# 𝑋
# X be the number of heads.
# Then
# 𝑋
# ∼
# Bin
# (
# 10
# ,
# 0.5
# )
# X∼Bin(10,0.5)
#
# Product Defects: Checking 20 products, each has a 5% chance of being defective.
# Let
# 𝑋
# X be the number of defective products.
# 𝑋
# ∼
# Bin
# (
# 20
# ,
# 0.05
# )
# X∼Bin(20,0.05)
#
#
# 6. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# The Central Limit Theorem (CLT) is a fundamental concept in statistics that states:
#
# When independent random variables are added, their normalized sum tends to follow a normal distribution, even if the original variables themselves are not normally distributed—provided the sample size is large enough.
#
# - Formal Definition:
# Let
# 𝑋
# 1
# ,
# 𝑋
# 2
# ,
# .
# .
# .
# ,
# 𝑋
# 𝑛
# X
# 1
# ​
#  ,X
# 2
# ​
#  ,...,X
# n
# ​
#   be a random sample of size
# 𝑛
# n from any population with:
#
# Mean
# 𝜇
# μ
#
# Standard deviation
# 𝜎
# σ
#
# Then, the sampling distribution of the sample mean
# 𝑋
# ˉ
# X
# ˉ
#   approaches a normal distribution as
# 𝑛
# →
# ∞
# n→∞:
#
# 𝑋
# ˉ
# ≈
# 𝑁
# (
# 𝜇
# ,
# 𝜎
# 2
# 𝑛
# )
# X
# ˉ
#  ≈N(μ,
# n
# σ
# 2
#
# ​
#  )
# Even if the original population is not normal!
#
# - Standardized Form (Z-score):
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# →
# 𝑁
# (
# 0
# ,
# 1
# )
# Z=
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#  →N(0,1)
#
# - Key Conditions:
# Independence: Observations should be independent.
#
# Sample Size: Large enough
# (
# 𝑛
# ≥
# 30
# )
# (n≥30) is often considered sufficient.
#
# Finite Mean and Variance: The original population must have a defined mean and standard deviation.
#
# - Why Is CLT So Important in Statistics?
#
# . Justifies Using the Normal Distribution
# CLT explains why the normal distribution appears so frequently in practice, even when the data is not normally distributed.
#
# . Foundation of Inferential Statistics
# Enables the use of confidence intervals, z-tests, t-tests, and hypothesis testing when the sample size is large.
#
# . Supports Statistical Modeling
# Many statistical methods (regression, control charts, ANOVA) rely on normality assumptions, made valid by CLT when sample sizes grow.
#
# . Makes Estimations Practical
# Allows estimation of population parameters (like mean) based on sample statistics, knowing that the distribution of those statistics is approximately normal.
#
#
# 7. What is the significance of confidence intervals in statistical analysis?
#
# A confidence interval (CI) is a range of values, derived from sample data, that is likely to contain the true population parameter (like the mean or proportion) with a specified level of confidence (commonly 95%).
#
# - Formal Definition:
# A confidence interval for a population parameter (like the mean
# 𝜇
# μ) is expressed as:
#
# Confidence Interval
# =
# Estimate
# ±
# Margin of Error
# Confidence Interval=Estimate±Margin of Error
# Example (95% CI for mean):
#
# 𝑋
# ˉ
# ±
# 𝑧
# ∗
# (
# 𝜎
# 𝑛
# )
# X
# ˉ
#  ±z
# ∗
#  (
# n
# ​
#
# σ
# ​
#  )
#
# Where:
#
# 𝑋
# ˉ
# X
# ˉ
#   = sample mean
#
# 𝑧
# ∗
# z
# ∗
#   = z-score corresponding to confidence level (e.g., 1.96 for 95%)
#
# 𝜎
# σ = population standard deviation
#
# 𝑛
# n = sample size
#
# SIGNIFICANCE:
#
# . Estimate Population Parameters
# CIs provide a range instead of a single number (point estimate), which better reflects uncertainty.
#
# Instead of saying "the average income is ₹30,000", we say, "We are 95% confident the average income is between ₹28,000 and ₹32,000."
#
# . Account for Sampling Variability
# Every sample is slightly different. CIs help capture that variability by giving a range where the true value likely lies.
#
# . Interpret Statistical Results More Clearly
# A CI gives more context than a p-value. It shows both:
#
# The magnitude of the estimate
#
# The precision (how wide or narrow the interval is)
#
# . Guide Decision Making
# In business, healthcare, and research, CIs help make decisions:
#
# “Is the drug effective?” → If the 95% CI for the treatment difference excludes 0, it likely is.
#
# . Used in Hypothesis Testing
# If the hypothesized value (e.g., mean = 0) lies outside the CI, we reject the null hypothesis.
#
#
#  8. What is the concept of expected value in a probability distribution?
#
# The expected value (also called mean or expectation) of a random variable is the long-run average outcome of a random process after many repetitions.
# It gives a measure of the center or "typical" value of a probability distribution.
#
# - Definition:
#
# For a random variable
# 𝑋
# X, the expected value, denoted by
# 𝐸
# (
# 𝑋
# )
# E(X) or
# 𝜇
# μ, is calculated as:
#
# - For a Discrete Random Variable:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑖
# 𝑥
# 𝑖
# ⋅
# 𝑃
# (
# 𝑥
# 𝑖
# )
# E(X)=
# i
# ∑
# ​
#  x
# i
# ​
#  ⋅P(x
# i
# ​
#  )
# Where:
#
# 𝑥
# 𝑖
# x
# i
# ​
#   = each possible value of the random variable
#
# 𝑃
# (
# 𝑥
# 𝑖
# )
# P(x
# i
# ​
#  ) = probability of that value
#
# - For a Continuous Random Variable:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∫
# −
# ∞
# ∞
# 𝑥
# ⋅
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# E(X)=∫
# −∞
# ∞
# ​
#  x⋅f(x)dx
# Where:
#
# 𝑓
# (
# 𝑥
# )
# f(x) = probability density function (PDF)
#
# - Interpretation:
# If you repeat the experiment many times, the average of all the outcomes will approach the expected value.
#
# It does not have to be a possible outcome itself.
#
# - Examples:
#
# . Rolling a Fair Die
#
# Possible outcomes: 1, 2, 3, 4, 5, 6
# Each has probability
# 1
# 6
# 6
# 1
# ​
#
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑖
# =
# 1
# 6
# 𝑥
# 𝑖
# ⋅
# 1
# 6
# =
# 1
# +
# 2
# +
# 3
# +
# 4
# +
# 5
# +
# 6
# 6
# =
# 21
# 6
# =
# 3.5
# E(X)=
# i=1
# ∑
# 6
# ​
#  x
# i
# ​
#  ⋅
# 6
# 1
# ​
#  =
# 6
# 1+2+3+4+5+6
# ​
#  =
# 6
# 21
# ​
#  =3.5
#
# We can't roll a 3.5, but on average, you'd expect this over many rolls.
#
# . Lottery Ticket Example
#
# Win ₹100 with probability 0.1
#
# Lose ₹20 with probability 0.9
#
# Let
# 𝑋
# X = profit:
#
# 𝐸
# (
# 𝑋
# )
# =
# (
# 100
# ×
# 0.1
# )
# +
# (
# −
# 20
# ×
# 0.9
# )
# =
# 10
# −
# 18
# =
# −
# 8
# E(X)=(100×0.1)+(−20×0.9)=10−18=−8
#
# Expected value = -₹8, meaning on average you lose ₹8 per ticket.
#
# - Properties of Expected Value:
#
# Linearity:
#
# 𝐸
# (
# 𝑎
# 𝑋
# +
# 𝑏
# )
# =
# 𝑎
# 𝐸
# (
# 𝑋
# )
# +
# 𝑏
# E(aX+b)=aE(X)+b
# Additivity (if
# 𝑋
# X and
# 𝑌
# Y are random variables):
#
# 𝐸
# (
# 𝑋
# +
# 𝑌
# )
# =
# 𝐸
# (
# 𝑋
# )
# +
# 𝐸
# (
# 𝑌
# )
# E(X+Y)=E(X)+E(Y)

# %%
#9.  Write a Python program to generate 1000 random numbers from a normal distribution with mean = 50 and standard deviation = 5. Compute its mean and standard  deviation using NumPy, and draw a histogram to visualize the distribution.

import numpy as np
import matplotlib.pyplot as plt

# Set parameters
mean = 50
std_dev = 5
sample_size = 1000

# Generate random numbers from a normal distribution
data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

# Compute statistics
computed_mean = np.mean(data)
computed_std = np.std(data)

# Print the results
print(f"Computed Mean: {computed_mean:.2f}")
print(f"Computed Standard Deviation: {computed_std:.2f}")

# Plot the histogram
plt.figure(figsize=(8, 5))
plt.hist(data, bins=30, color='skyblue', edgecolor='black', density=True)
plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.axvline(computed_mean, color='red', linestyle='dashed', linewidth=1.5, label=f"Mean = {computed_mean:.2f}")
plt.legend()
plt.show()
# Out:
# Computed Mean: 50.18
# Computed Standard Deviation: 5.02

# %% [markdown]
# 10.  You are working as a data analyst for a retail company. The company has
# collected daily sales data for 2 years and wants you to identify the overall sales trend.
# daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
# 235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
#
# ● Explain how you would apply the Central Limit Theorem to estimate the average sales
# with a 95% confidence interval.
#
# ● Write the Python code to compute the mean sales and its confidence interval?
#
#
# i. How to Apply the Central Limit Theorem (CLT)
#
# The Central Limit Theorem states that the sampling distribution of the sample mean will be approximately normal, even if the original data is not, as long as the sample size is large or samples are randomly drawn and independent.
#
# Since ywe have daily sales data, ywe can use the sample of 20 days to:
#
# Compute the sample mean and standard deviation.
#
# Use CLT to construct a 95% confidence interval for the true mean daily sales of the population.
#
# The 95% confidence interval formula is:
#
# CI
# =
# 𝑥
# ˉ
# ±
# 𝑧
# ∗
# ⋅
# (
# 𝑠
# 𝑛
# )
# CI=
# x
# ˉ
#  ±z
# ∗
#  ⋅(
# n
# ​
#
# s
# ​
#  )
# Where:
#
# 𝑥
# ˉ
# x
# ˉ
#   = sample mean
#
# 𝑠
# s = sample standard deviation
#
# 𝑛
# n = sample size (20)
#
# 𝑧
# ∗
# =
# 1.96
# z
# ∗
#  =1.96 for 95% confidence (from standard normal table)

# %%
#ii. Write the Python code to compute the mean sales and its confidence interval?

import numpy as np
import scipy.stats as stats

# Daily sales data for 20 days
daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]

# Convert to NumPy array
sales = np.array(daily_sales)

# Sample statistics
mean_sales = np.mean(sales)
std_sales = np.std(sales, ddof=1)  # Sample standard deviation
n = len(sales)

# Confidence level and z-score
confidence = 0.95
z_score = stats.norm.ppf(1 - (1 - confidence) / 2)

# Margin of error
margin_of_error = z_score * (std_sales / np.sqrt(n))

# Confidence interval
lower_bound = mean_sales - margin_of_error
upper_bound = mean_sales + margin_of_error

# Output
print(f"Mean Sales: {mean_sales:.2f}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Mean Sales: 248.25
# 95% Confidence Interval: (240.68, 255.82)
